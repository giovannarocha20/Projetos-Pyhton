# %% [markdown]
# ## Atividade 1
# Plote um gráfico da função
# 𝑦
# =
# 5
# 𝑥
# +
# 1
# y=5x+1 para valores de
# 𝑥
# x entre 0 e 10.
#
# Utilize marcadores do tipo quadrado nos pontos (
# 𝑥
# x,
# 𝑦
# y).
# Adicione um título ao gráfico e rótulos para os eixos
# 𝑥
# x e
# 𝑦
# y.
# A linha da reta deve ser azul e os marcadores quadrados devem ser vermelhos.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 11)
y = 5 * x + 1

plt.plot(x, y, label="y = 5x + 1", color='blue')
plt.scatter(x, y, color='red', label="Pontos", marker='s')

plt.title("Gráfico da função y = 5x + 1")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Atividade 2
# Crie um gráfico de linhas que mostre o valor do Real em relação ao Dólar entre os anos de 2016 e 2022.
#
# Utilize os seguintes valores fictícios para o câmbio:
# 2016: 3.15
# 2017: 3.26
# 2018: 3.88
# 2019: 4.30
# 2020: 5.33
# 2021: 5.45
# 2022: 5.39
# Adicione título ao gráfico e rótulos para os eixos
# 𝑥
# x (Ano) e
# 𝑦
# y (Valor em R$).
# Inclua marcadores nos pontos do gráfico e mostre uma grade.

# %%
anos = [2016, 2017, 2018, 2019, 2020, 2021, 2022]
valores = [3.15, 3.26, 3.88, 4.30, 5.33, 5.45, 5.39]

plt.plot(anos, valores, marker='o', linestyle='-', color='blue', label="Valor do Real em relação ao Dólar")

plt.title("Valor do Real em relação ao Dólar (dados fictícios)")
plt.xlabel("Ano")
plt.ylabel("Valor (R$)")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Atividade 3
# Faça o mesmo gráfico da Atividade 2, mas agora utilizando barras.
#
# Os dados permanecem os mesmos (valor do Real em relação ao Dólar de 2016 a 2022).
# Adicione título ao gráfico e rótulos para os eixos
# 𝑥
# x (Ano) e
# 𝑦
# y (Valor em R$).
# Mostre também uma grade no eixo
# 𝑦
# y.

# %%
plt.bar(anos, valores, color='orange', label="Valor do Real em relação ao Dólar")

plt.title("Valor do Real em relação ao Dólar (Gráfico de Barras)")
plt.xlabel("Ano")
plt.ylabel("Valor (R$)")
plt.legend()
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ## Atividade 4
# Com base nos dados da Atividade 2, plote dois gráficos separados lado a lado:
#
#
# O gráfico da variação do valor do Dólar em relação ao Real (valores fictícios da Atividade 2).
# O gráfico do PIB per capita do Brasil nos mesmos anos (dados fictícios):
#
#
# 2016: 8710.50 USD
#
#
# 2017: 9928.50 USD
#
#
# 2018: 9151.58 USD
#
#
# 2019: 8897.29 USD
#
#
# 2020: 6795.32 USD
#
#
# 2021: 7500.21 USD
#
#
# 2022: 7542.34 USD
#
#
# Escolha o tipo de gráfico mais adequado para cada conjunto de dados (linha para o primeiro e barras para o segundo).
# Adicione títulos e rótulos para os eixos em ambos os gráficos.

# %%
pib = [8710.50, 9928.50, 9151.58, 8897.29, 6795.32, 7500.21, 7542.34]

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(anos, valores, marker='o', color='blue')
axs[0].set_title("Variação Dólar x Real")
axs[0].set_xlabel("Ano")
axs[0].set_ylabel("Valor (R$)")
axs[0].grid()

axs[1].bar(anos, pib, color='green')
axs[1].set_title("PIB per Capita do Brasil")
axs[1].set_xlabel("Ano")
axs[1].set_ylabel("PIB (USD)")
axs[1].grid(axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Atividade 5
# Crie um gráfico de pizza para representar os destinos de exportação do Brasil.
#
# Use os seguintes percentuais:
#
#
# China: 30%
#
#
# Estados Unidos: 40%
#
#
# Europa: 20%
#
#
# Outros: 10%
#
#
# Adicione rótulos aos setores e exiba os percentuais no gráfico.

# %%
destinos = ["China", "Estados Unidos", "Europa", "Outros"]
percentuais = [30, 40, 20, 10]

plt.pie(percentuais, labels=destinos, autopct='%1.1f%%', startangle=90, colors=['red', 'blue', 'green', 'grey'])

plt.title("Destino de exportações do Brasil")

plt.show()

# %% [markdown]
# ## Atividade 6
# Crie um gráfico de dispersão mostrando a relação entre peso e altura.
#
# Use os seguintes dados:
#
# Alturas (m): [1.60, 1.62, 1.65, 1.65, 1.70, 1.70, 1.75, 1.80, 1.85, 1.90, 1.90, 1.95, 2.00]
#
# Pesos (kg): [60, 61, 64, 67, 70, 73, 75, 80, 85, 90, 85, 1.95, 2.00]
#
# Adicione um título e rótulos aos eixos
# 𝑥
# (Altura) e
# 𝑦
# (Peso).

# %%
altura = [1.60, 1.62, 1.65, 1.65, 1.70, 1.70, 1.75, 1.80, 1.85, 1.90, 1.90, 1.95, 2.00]
peso = [60, 61, 64, 67, 70, 73, 75, 80, 85, 90, 85, 1.95, 2.00]

plt.scatter(altura, peso, color='purple', label="Relação Peso x Altura")

plt.title("Dispersão: Relação Peso x Altura")
plt.xlabel("Altura (m)")
plt.ylabel("Peso (kg)")
plt.legend()
plt.grid()

plt.show()
